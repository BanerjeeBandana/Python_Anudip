# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with 'Team Member' and 'TPT' columns

# Set the style of seaborn
sns.set(style="whitegrid")

# Get the number of unique Team Members
num_unique_team_members = df['Team Member'].nunique()

# Create a custom color palette with the required number of colors
custom_palette = sns.color_palette("Set3", n_colors=num_unique_team_members)

# Create a boxplot for individual Team Members
plt.figure(figsize=(12, 6))
sns.boxplot(x='Team Member', y='TPT', data=df,palette=custom_palette)

# Set the title and labels
plt.title('Boxplot for Team Members and TPT')
plt.xlabel('Team Member')
plt.ylabel('TPT')
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# C:\Users\Bandana\AppData\Local\Temp\ipykernel_15916\198872323.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Team Member', y='TPT', data=df,palette=custom_palette)
